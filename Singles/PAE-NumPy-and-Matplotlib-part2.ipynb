# %% [markdown]
# # Matplotlib
# ---

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# ## Plot function

# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-1,1,20)
y = x**2
plt.plot(x,y)
